# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from urllib.parse import urljoin
import pandas as pd


table=[]
target_url="https://www.rottentomatoes.com"
target_links=[]
#get the main oage
def request(url):
    try:
        r=requests.get(url)
        return r.content

    except:
        print('request error')
        pass

#extract links
def extract_movie_links(url):
    r=request(url)
    list=[]
    try:
        soup=BeautifulSoup(r ,  "html.parser")
        link_list= soup.find_all('a',{'class' :'unstyled articleLink'})
        for link in link_list:
            if "/m/" in str(link):
                link=link['href']
                link=urljoin('https://www.rottentomatoes.com',link)
                list.append(link)
        return list[0:19]
    except:
        print('extract error')
#extract_movie_links('https://www.rottentomatoes.com/top/bestofrt/')
#go to link and collect data
def scrape_data(url):

    r=request(url)
    try:

        soup=BeautifulSoup(r ,  "html.parser")
        movie_title=soup.find('h1',{'data-type' :'title'}).text
        movie_title = ''.join(movie_title.split())
        print(movie_title)
        tomatometer=int(soup.find('div',{'class':'critic-score'}).contents[1].contents[3].contents[0].text)
        print(tomatometer)
        audience_score=int(soup.find('div',{'class':'meter-value'}).contents[1].text.split('%')[0])
        print(audience_score)
        director=soup.find('ul',{'class' :'content-meta info'}).contents[5].contents[3].contents[1].text
        print(director)
        genre=soup.find('ul',{'class' :'content-meta info'}).contents[3].contents[3].contents[1].text
        genre = ''.join(genre.split())
        print(genre)
        try:
            runtime=soup.find('ul',{'class' :'content-meta info'}).contents[13].contents[3].contents[1].text
            runtime = int(''.join(runtime.split()).split('minutes')[0])
            print(runtime)
        except:
            try:
                runtime=soup.find('ul',{'class' :'content-meta info'}).contents[15].contents[3].contents[1].text
                runtime = int(''.join(runtime.split()).split('minutes')[0])
                print(runtime)
            except:
                runtime="none"

        try:
            poster_url= soup.find('img',{'class' :'posterImage'})['src']
            print(poster_url)
        except:
            poster_url='none'
        try:
            background_url=soup.find('div', {'class':'heroImage movie'})['style'].split("url('")[1].split("'")[0]
            print(background_url)
        except:
            try:
                background_url=soup.find('div', {'class':'heroImage movie noCursor'})['style'].split("url('")[1].split("'")[0]
                print(background_url)

            except:
                background_url="none"





        #create dictonary
        data={'title':movie_title,
        'tomatometer':tomatometer,
        'audience_score':audience_score,
        'director':director,
        'genre':genre,
        'runtime':runtime,
        'poster_url':poster_url,
        'background_url':background_url}
        #print(data)
        return data
    except:
        pass

def crawl(url):


    #get all movie links on page
    link_list=extract_movie_links(url)

    #scrape data for that movie
    for link in link_list:
        #print(link)
        data=scrape_data(link)
        table.append(data)

# %%
crawl('https://www.rottentomatoes.com/top/bestofrt/top_100_documentary_movies/')

print(pd.DataFrame(table))
# Out:
# IAmNotYourNegro
# 98
# 83
# Raoul Peck
# Documentary
# 93
# https://resizing.flixster.com/G3vtcQ_sGyhmdgAE82UyhEPeoQg=/206x305/v1.bTsxMjI3MDI5OTtqOzE3ODI3OzEyMDA7MTM4MjsyMDQ4
# https://resizing.flixster.com/T1UNdk8YPdnulsRU6Om_sMuLXbY=/740x290/v1.bjsxMjcwMDM3O2o7MTc4MzQ7MTIwMDsyMDAwOzE0NDA
# Anvil!TheStoryofAnvil(2009)
# 98
# 90
# Sacha Gervasi
# Documentary
# 90
# https://resizing.flixster.com/P8YcBl6PMINpqFRPCGYXpfuKeNw=/206x305/v1.bTsxMTIyMzUzMDtqOzE3OTA0OzEyMDA7MTUzNjsyMDQ4
# BrightLights:StarringCarrieFisherandDebbieReynolds(2017)
# 100
# 85
# Alexis Bloom
# Documentary
# https://resizing.flixster.com/dAFjO_HIFVaCrS2KFxnDyqQq71E=/206x305/v1.bTsxMjMwMjA1MztqOzE3ODI3OzEyMDA7MTYyODsyNDQ0
# TheMissingPicture2014
# 99
# 76
# Rithy Panh
# Documentary
# 96
# https://resizing.flixster.com/m7NdufrtjhWomLk8eCTJ1rgLJJs=/206x305/v1.bTsxMTE3Mzk3OTtqOzE3OTA0OzEyMDA7Mjg0OzQwNQ
# https://resizing.flixster.com/kxS3NWD11w8-kc_5FtBRl6ISNkQ=/740x290/v1.bjsxNTg3MTtqOzE3ODIwOzEyMDA7NTMzMjsyNjY2
#     audience_score                                     background_url  \
# 0               83  https://resizing.flixster.com/T1UNdk8YPdnulsRU...
# 1               87  https://resizing.flixster.com/CQCvNiL9YwDEoEzj...
# 2               88  https://resizing.flixster.com/3HboNzSVZuMyWEv2...
# 3               82  https://resizing.flixster.com/wEXzDRm-SC5ImZb1...
# 4               94                                               none
# 5               89  https://resizing.flixster.com/aLumzD3UYfEya8oI...
# 6               87  https://resizing.flixster.com/8XiUcU1db3FHuxHm...
# 7               89  https://resizing.flixster.com/sIoWuBd5KF51O4vr...
# 8               84  https://resizing.flixster.com/qy5gBuPNocJbP6v2...
# 9               90  https://resizing.flixster.com/qWv7iQuBWpPSFmp5...
# 10              89  https://resizing.flixster.com/y8B_bmXPD5J6HBGp...
# 11              89                                               none
# 12              83  https://resizing.flixster.com/MEMLFlmkPpve4ISp...
# 13              91  https://resizing.flixster.com/yMC5nSD3I14BGLOt...
# 14              89                                               none
# 15              79  https://resizing.flixster.com/CcWJoS3dP_BBr5dX...
# 16              90                                               none
# 17              85                                               none
# 18              76  https://resizing.flixster.com/kxS3NWD11w8-kc_5...
#
#                    director                   genre  \
# 0                Raoul Peck             Documentary
# 1               James Marsh             Documentary
# 2          Steve James (II)             Documentary
# 3            Morgan Neville             Documentary
# 4           Martin Scorsese             Documentary
# 5            Keith Maitland               Animation
# 6              Asif Kapadia  ArtHouse&International
# 7               Alex Gibney             Documentary
# 8               Ceyda Torun             Documentary
# 9    Gabriela Cowperthwaite             Documentary
# 10         Henry Alex Rubin             Documentary
# 11             Frank Pavich             Documentary
# 12          Elyse Steinberg             Documentary
# 13  Charles Ferguson (III)              Documentary
# 14                 Amy Berg             Documentary
# 15              Ethan Hawke             Documentary
# 16            Sacha Gervasi             Documentary
# 17             Alexis Bloom             Documentary
# 18               Rithy Panh             Documentary
#
#                                            poster_url runtime  \
# 0   https://resizing.flixster.com/G3vtcQ_sGyhmdgAE...      93
# 1   https://resizing.flixster.com/aoSDjVxhulRQpMdi...      94
# 2   https://resizing.flixster.com/4eRPkXQjdrVJw4mV...     120
# 3   https://resizing.flixster.com/u_vDQZZ-yyCPVr-1...      89
# 4   https://resizing.flixster.com/dk9l0RiItlo5LKjV...    none
# 5   https://resizing.flixster.com/ZpXEzyJfCZko3cF4...      82
# 6   https://resizing.flixster.com/-2yJ6FSdiOdc4zF5...     128
# 7   https://resizing.flixster.com/pCghVJ4YYvIi3pOp...     106
# 8   https://resizing.flixster.com/IsNpXAz1cpMBjJuf...      79
# 9   https://resizing.flixster.com/mgEV2QHaV_rMlanO...      80
# 10  https://resizing.flixster.com/dGXuFGVAWhCDstMn...      85
# 11  https://resizing.flixster.com/HQoa2BCWZog7LYa8...    none
# 12  https://resizing.flixster.com/bNJdDZbOZDs-2HqK...      96
# 13  https://resizing.flixster.com/oJWdTlq76uN_6uIS...     108
# 14  https://resizing.flixster.com/XtuhoTQK9ba9k1cd...     101
# 15  https://resizing.flixster.com/navNxxq6bvRhyDIa...      84
# 16  https://resizing.flixster.com/P8YcBl6PMINpqFRP...      90
# 17  https://resizing.flixster.com/dAFjO_HIFVaCrS2K...    none
# 18  https://resizing.flixster.com/m7NdufrtjhWomLk8...      96
#
#                                                 title  tomatometer
# 0                                     IAmNotYourNegro           98
# 1                                       ManonWire2008          100
# 2                                      LifeItself2014           97
# 3                               20FeetFromStardom2013           99
# 4                                  TheLastWaltz(1978)           98
# 5                                               Tower          100
# 6                                                 Amy           95
# 7                               TaxitotheDarkSide2007          100
# 8                                                Kedi           98
# 9                                       Blackfish2013           98
# 10                                     Murderball2005           98
# 11                             Jodorowsky'sDune(2014)           98
# 12                                             Weiner           96
# 13                                      InsideJob2010           98
# 14                            DeliverUsfromEvil(2006)          100
# 15                             Seymour:AnIntroduction          100
# 16                        Anvil!TheStoryofAnvil(2009)           98
# 17  BrightLights:StarringCarrieFisherandDebbieReyn...          100
# 18                              TheMissingPicture2014           99

# %%
print(pd.DataFrame(table))
# Out:
#     audience_score                                     background_url  \
# 0               83  https://resizing.flixster.com/T1UNdk8YPdnulsRU...
# 1               87  https://resizing.flixster.com/CQCvNiL9YwDEoEzj...
# 2               88  https://resizing.flixster.com/3HboNzSVZuMyWEv2...
# 3               82  https://resizing.flixster.com/wEXzDRm-SC5ImZb1...
# 4               94                                               none
# 5               89  https://resizing.flixster.com/aLumzD3UYfEya8oI...
# 6               87  https://resizing.flixster.com/8XiUcU1db3FHuxHm...
# 7               89  https://resizing.flixster.com/sIoWuBd5KF51O4vr...
# 8               84  https://resizing.flixster.com/qy5gBuPNocJbP6v2...
# 9               90  https://resizing.flixster.com/qWv7iQuBWpPSFmp5...
# 10              89  https://resizing.flixster.com/y8B_bmXPD5J6HBGp...
# 11              89                                               none
# 12              83  https://resizing.flixster.com/MEMLFlmkPpve4ISp...
# 13              91  https://resizing.flixster.com/yMC5nSD3I14BGLOt...
# 14              89                                               none
# 15              79  https://resizing.flixster.com/CcWJoS3dP_BBr5dX...
# 16              90                                               none
# 17              85                                               none
# 18              76  https://resizing.flixster.com/kxS3NWD11w8-kc_5...
#
#                    director                   genre  \
# 0                Raoul Peck             Documentary
# 1               James Marsh             Documentary
# 2          Steve James (II)             Documentary
# 3            Morgan Neville             Documentary
# 4           Martin Scorsese             Documentary
# 5            Keith Maitland               Animation
# 6              Asif Kapadia  ArtHouse&International
# 7               Alex Gibney             Documentary
# 8               Ceyda Torun             Documentary
# 9    Gabriela Cowperthwaite             Documentary
# 10         Henry Alex Rubin             Documentary
# 11             Frank Pavich             Documentary
# 12          Elyse Steinberg             Documentary
# 13  Charles Ferguson (III)              Documentary
# 14                 Amy Berg             Documentary
# 15              Ethan Hawke             Documentary
# 16            Sacha Gervasi             Documentary
# 17             Alexis Bloom             Documentary
# 18               Rithy Panh             Documentary
#
#                                            poster_url runtime  \
# 0   https://resizing.flixster.com/G3vtcQ_sGyhmdgAE...      93
# 1   https://resizing.flixster.com/aoSDjVxhulRQpMdi...      94
# 2   https://resizing.flixster.com/4eRPkXQjdrVJw4mV...     120
# 3   https://resizing.flixster.com/u_vDQZZ-yyCPVr-1...      89
# 4   https://resizing.flixster.com/dk9l0RiItlo5LKjV...    none
# 5   https://resizing.flixster.com/ZpXEzyJfCZko3cF4...      82
# 6   https://resizing.flixster.com/-2yJ6FSdiOdc4zF5...     128
# 7   https://resizing.flixster.com/pCghVJ4YYvIi3pOp...     106
# 8   https://resizing.flixster.com/IsNpXAz1cpMBjJuf...      79
# 9   https://resizing.flixster.com/mgEV2QHaV_rMlanO...      80
# 10  https://resizing.flixster.com/dGXuFGVAWhCDstMn...      85
# 11  https://resizing.flixster.com/HQoa2BCWZog7LYa8...    none
# 12  https://resizing.flixster.com/bNJdDZbOZDs-2HqK...      96
# 13  https://resizing.flixster.com/oJWdTlq76uN_6uIS...     108
# 14  https://resizing.flixster.com/XtuhoTQK9ba9k1cd...     101
# 15  https://resizing.flixster.com/navNxxq6bvRhyDIa...      84
# 16  https://resizing.flixster.com/P8YcBl6PMINpqFRP...      90
# 17  https://resizing.flixster.com/dAFjO_HIFVaCrS2K...    none
# 18  https://resizing.flixster.com/m7NdufrtjhWomLk8...      96
#
#                                                 title  tomatometer
# 0                                     IAmNotYourNegro           98
# 1                                       ManonWire2008          100
# 2                                      LifeItself2014           97
# 3                               20FeetFromStardom2013           99
# 4                                  TheLastWaltz(1978)           98
# 5                                               Tower          100
# 6                                                 Amy           95
# 7                               TaxitotheDarkSide2007          100
# 8                                                Kedi           98
# 9                                       Blackfish2013           98
# 10                                     Murderball2005           98
# 11                             Jodorowsky'sDune(2014)           98
# 12                                             Weiner           96
# 13                                      InsideJob2010           98
# 14                            DeliverUsfromEvil(2006)          100
# 15                             Seymour:AnIntroduction          100
# 16                        Anvil!TheStoryofAnvil(2009)           98
# 17  BrightLights:StarringCarrieFisherandDebbieReyn...          100
# 18                              TheMissingPicture2014           99
